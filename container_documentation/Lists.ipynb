# %% [markdown]
# <a href="https://colab.research.google.com/github/anushka-220/Machine-Learning/blob/main/Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **<ins>PYTHON LISTS DOCUMENTATION</ins>**
#
#
# <h10>Lists are one of the four built-in data type in Python. (Other three being Tuple, set , dictionary).
#
#
# A list contains series of any data type : strings, int, boolean, other lists.
#
#
# They are defined by enclosing elements in square brackets and separating them with commas.</h10>

# %%
#Example of a list
list= ['red', 'orange', 'yellow']
print(list)
# Out:
# ['red', 'orange', 'yellow']

# %%
#List can store different data types
list1=[1,'apple', 4.89,[2,3,4], (1,2,3), {1:"hello", 2:"world"}]
print(list1)
# Out:
# [1, 'apple', 4.89, [2, 3, 4], (1, 2, 3), {1: 'hello', 2: 'world'}]

# %% [markdown]
# Lists are a **`mutable data type`**, i.e., they can be changed and manipulated. Lists even allows duplication of values.

# %% [markdown]
# **<ins>MEMORY REPRESENTATION</ins>**
#
# Using standard indexing scheme, the first element is at index 0, the next at 1, and so on upto length-1.
#
#
# `**What is a dynamic array?**`
#
# A dynamic array is similar to an array, but with the difference that its size can be dynamically modified at runtime.
#
# We don’t need to specify how much large an array beforehand. The elements of an array occupy a contiguous block of memory, and once created, its size cannot be changed. A dynamic array can, once the array is filled, allocate a bigger chunk of memory, copy the contents from the original array to this new space, and continue to fill the available slots.
# In Python, a list is a dynamic array, which means it can grow or shrink in size.
#
# The elements of the list are stored in contiguous memory locations, and each element is a reference to an object. This allows for flexibility in the types of elements that can be stored in a list.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Source of the image: https://www.geeksforgeeks.org/implementation-of-dynamic-array-in-python/

# %% [markdown]
# **BASIC OPERATIONS :**

# %% [markdown]
# 1) len()

# %%
num=[1,2,3,23,10,9,6]

#To find the length of the list
l=len(list)
print("Length of the list=",l)
# Out:
# Length of the list= 3

# %% [markdown]
# 2) append()

# %%
#To add an element to the list we use append function
num.append(4)
print("New list after appending element=",num)

#To change an item of the list
num[2]= 7
print ("Changed list=",num)

#To access individual elements we use the index number
first_ele= num[0]
print("First element=",first_ele)
# Out:
# New list after appending element= [1, 2, 3, 23, 10, 9, 6, 4]
# Changed list= [1, 2, 7, 23, 10, 9, 6, 4]
# First element= 1

# %% [markdown]
# 3)insert()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Source of the image: https://www.tutorialkart.com/python/python-list-insert/#gsc.tab=0

# %%
#Since append adds an element to the end of the list, if we want to add an element at a certain posiiton we use insert() method
#insert the element=18 at index 1 (second position)
num.insert(1,18)

print("After insertion of new element=",num)
# Out:
# After insertion of new element= [1, 18, 2, 7, 23, 10, 9, 6, 4]

# %% [markdown]
# 4) del statement

# %%
#To remove one or more item from the list we use del statement
#To delete the third item
del num[3]
print("After deleting 3rd item=",num)
# Out:
# After deleting 3rd item= [1, 18, 2, 23, 10, 9, 6, 4]

# %%
#To delete last item
del num[-1]
print("After deleting last item=",num)
# Out:
# After deleting last item= [1, 18, 2, 23, 10, 9, 6]

# %%
#To delete first two items
del num[0:2]
print("After deleting first two items",num)
# Out:
# After deleting first two items [2, 23, 10, 9, 6]

# %% [markdown]
# 5) clear()

# %%
#To remove all items from the list we use clear
num.clear()
print("Cleared list=",num)
#This is equivalent to del num[:]
# Out:
# Cleared list= []

# %% [markdown]
# 6) copy()

# %%
#To deep copy

# results in a completely independent copy of l, including all nested elements

import copy
l=[1,2,3,45]
l2=copy.deepcopy(l)
print(l2)
# Out:
# [1, 2, 3, 45]

# %%
#To shallow copy

#preservs the top-level structure but sharing references to the inner list

l3=copy.copy(l2)
print(l3)
# Out:
# [1, 2, 3, 45]

# %% [markdown]
# 7) count()

# %%
#eturns the count of the occurrences of a given element in a list
l=[1,1,3,4,5,77,8,1]
l.count(1)
# Out:
# 3

# %% [markdown]
# 8) min()

# %%
#returns the smallest of the values or the smallest item in an iterable passed as its parameter
min(l)
# Out:
# 1

# %% [markdown]
# 9) max()

# %%
#returns the largest of the value or the largest item in an iterable passes as its parameter
max(l)
# Out:
# 77

# %% [markdown]
# 10) sum()

# %%
total=sum(l)
print(total)
# Out:
# 100

# %% [markdown]
# **Negative Indexing:**
#
#
# Lists allow negative indexing for its sequences. The index of -1 refers to the last item , -2 to the second last and so on.

# %%
languages = ["Python", "Swift", "C++"]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Source of the image: https://www.programiz.com/python-programming/list

# %% [markdown]
# Note: If the specified index does not exist in a list, Python throws the IndexError exception.

# %% [markdown]
# **Below are some more specialized list functions:**
#
# <ins>1) pop()</ins> :
#
#
#    Removes the element from the end of the list and returns it, decreasing the length by 1

# %%
my_list=['a','b','c','d']
my_list.pop()
# Out:
# 'd'

# %%
#To remove a certain element at an index
my_list.pop(1)
# Out:
# 'b'

# %% [markdown]
# <ins>2) remove()</ins> :
#
#
#    list.remove(element) searches for the first occurrence of the element in the list and removes it. Unlike pop, it uses the actual value of the element to search for it in the list.
#
#    It gives ValueError if the element is not found in the list.

# %%
list=[1,2,3,2,4,3,5]
list.remove(3)
print(list)
# Out:
# [1, 2, 2, 4, 3, 5]

# %% [markdown]
# <ins>3) extend()</ins> :
#    list1.extend(list2)
#    We can add all the elements of list2 at the end of list1. This is different from append because here we can add all elements of the list instead of just one

# %%
list1=['a','b','c']
list2=[1,2,3]
list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %% [markdown]
# <ins>4) index()</ins> :
#
#
#    list.index(x)
#    Checks for the first occurence of the element in list and returns its index.
#
#    ValueError is raised when the element is not found in the list.

# %%
list=[1,2,3,4,5,6]
list.index(4)
# Out:
# 3

# %% [markdown]
# **Slicing Lists**
#
# We can pull out certain parts of list

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Source of the image: https://railsware.com/blog/indexing-and-slicing-for-lists-tuples-strings-sequential-types/

# %%
#To give the elements from index 1 to index 3
subset=list[1:4]
print(subset)
# Out:
# [2, 3, 4]

# %%
#To get all elements till index 1
new=list[:2]
print(new)
# Out:
# [1, 2]

# %%
#To get all elements from index 2 to the end
new=list[2:]
print(new)
# Out:
# [3, 4, 5, 6]

# %%
#To take every nth element of the list
print(list)
list[::2]
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 3, 5]

# %%
#We can even provide a start value

list[1::2]
# Out:
# [2, 4, 6]

# %%
#We can also add the stop parameter

list[1:-3:2]
# Out:
# [2]

# %%
#Creating a slice object
#we can use slice function
func=slice(2,7)
nums=[10,20,30,40,50,60,70,80,90]
nums[func]

#We use this when we need to repeat the slicing function over and over
# Out:
# [30, 40, 50, 60, 70]

# %%
#Substitute part of a list
print("Before substituting ",nums)
nums[:4]=[12,13,14,15]
print("After substituting ",nums)
# Out:
# Before substituting  [10, 20, 30, 40, 50, 60, 70, 80, 90]
# After substituting  [12, 13, 14, 15, 50, 60, 70, 80, 90]

# %%
#To replace a part of the list with a bigger set of elements
nums[:4]=[1,2,3,4,5,6,7,8,9]
print("after replacing with bigger set of elements: ",nums)
# Out:
# after replacing with bigger set of elements:  [1, 2, 3, 4, 5, 6, 7, 8, 9, 50, 60, 70, 80, 90]

# %%
#Similarly we can also do the same with a smaller set of elements
nums[:4]=[1,2]
print("after replacing with smaller set of elements: ", nums)
# Out:
# after replacing with smaller set of elements:  [1, 2, 5, 6, 7, 8, 9, 50, 60, 70, 80, 90]

# %%
#We can also perform slice deletion
del nums[::2]
print(nums)
# Out:
# [2, 6, 8, 50, 70, 90]

# %% [markdown]
# **Iterable**
#
# We can use loops to iterate through the lists. We can also use this feature to sort the list.

# %%
#To print all the elements of the array
n=[23,56,12,10,3,6,45]
for elements in n:
    print(elements)
# Out:
# 23
# 56
# 12
# 10
# 3
# 6
# 45

# %%
#Another way to do the same
lenght=len(n)
for element in range(0,lenght):
    print(n[element])
# Out:
# 23
# 56
# 12
# 10
# 3
# 6
# 45

# %%
#To sort a list in ascending order
n.sort()
print(n)
# Out:
# [3, 6, 10, 12, 23, 45, 56]

# %%
#To sort in descending order
n.sort(reverse=True)
print(n)
# Out:
# [56, 45, 23, 12, 10, 6, 3]

# %% [markdown]
# Custom Sorting with 'sorted()'
#
# You can also use the key parameter with sorted() to define a custom sorting criterion

# %%
words = ["apple", "banana", "kiwi", "orange"]

# Sort the list of words by length
sorted_words_by_length = sorted(words, key=len)
print(sorted_words_by_length)
# Output: ['kiwi', 'apple', 'banana', 'orange']
# Out:
# ['kiwi', 'apple', 'banana', 'orange']

# %% [markdown]
# **Using Lists as Stacks**
#
# Stack is a linear data structure that follows a particular order in which the operations are performed. The order is LIFO(Last In First Out).
#
# LIFO implies that the element that is inserted last, comes out first and FILO implies that the element that is inserted first, comes out last.
#
# Using lists, we can easily implement stack in Python.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Source of the image : https://www.scaler.com/topics/stack-in-python/

# %%
#To push elements in stack
stack=[5,6,7,8]
stack.append(9)
stack.append(10)
stack.append(12)
print(stack)
# Out:
# [5, 6, 7, 8, 9, 10, 12]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Source of the image: https://www.scaler.com/topics/stack-in-python/

# %%
#To remove elements from top
stack.pop()
print(stack)
stack.pop()
print(stack)
# Out:
# [5, 6, 7, 8, 9, 10]
# [5, 6, 7, 8, 9]

# %% [markdown]
# **Using Lists as a Queue**
#
# A queue is a data structure that follows the First-In, First-Out (FIFO) principle, meaning the first element added is the first one to be removed.
#
#  While lists are not the most efficient data structure for queues (due to the pop(0) operation having linear time complexity), you can use append() to enqueue and pop(0) to dequeue elements

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Source of the image: https://www.studytonight.com/post/implementing-queue-in-python

# %%
queue=[]
 #Enqueue elements
queue.append('apple')
queue.append('mango')
queue.append('orange')
print(queue)
# Out:
# ['apple', 'mango', 'orange']

# %%
#To dequeue
front_element=queue.pop(0)
print(front_element)
print(queue)
# Out:
# apple
# ['mango', 'orange']

# %% [markdown]
# Note: Using pop(0) on a list can be inefficient for large lists because it requires shifting all remaining elements to fill the gap.

# %% [markdown]
# **List Comprehension**
#
#
#
#  It provides a more compact syntax for creating a list based on an existing iterable (e.g., another list, range, string, etc.) and applying a specified expression or condition to each element.
#
#  Syntax:
#  list=[expression for item in iterable if condition]

# %%
#To create a list of squares
sq=[x**2 for x in range (1,10)]
print(sq)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
#To convert a string to a list of characters
word='Donut'
charac=[char for char in word]
print(charac)
# Out:
# ['D', 'o', 'n', 'u', 't']

# %%
#Matrix using list comprehension

matrix = [[j for j in range(3)] for i in range(3)]

print(matrix)
# Out:
# [[0, 1, 2], [0, 1, 2], [0, 1, 2]]

# %% [markdown]
# List comprehensions are not only concise but also often more readable than equivalent code using traditional loops.
