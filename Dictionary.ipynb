# %% [markdown]
# <a href="https://colab.research.google.com/github/anushka-220/Machine-Learning/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **<ins>DICTIONARY</ins>**
#
# Dictionaries are built-in data types in Python.Dictionaries are mutable, and can contain key:value pairs.
#
# In Python 3.7 and later, dictionaries maintain the insertion order of their items, which means they are ordered.
#
#
# Values in a dictionary can be of any data type and can be duplicated, whereas keys can’t be repeated and must be immutable.
#
#
# Dictionaries in Python differ from sequences in that they are indexed by keys instead of a range of numbers. These keys can be of any immutable type, making strings and numbers suitable candidates. Tuples can also serve as keys if they solely consist of strings, numbers, or other tuples. However, if a tuple contains any mutable object, either directly or indirectly, it cannot be utilized as a key.
#
# Importantly, lists cannot function as keys in dictionaries due to their mutability. Lists can be modified in place using operations such as index assignments, slice assignments, and methods like append() and extend(). This mutability prevents them from serving as reliable keys for dictionary indexing.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Source of image: https://www.scaler.com

# %%
#To create empty dictionary
dic={}
print(dic)
# Out:
# {}

# %%
#Adding key:value pairs
dic={1:'a',2:'b',3:'c'}
print(dic)
# Out:
# {1: 'a', 2: 'b', 3: 'c'}

# %%
#When we take list as a key it returns Type error
dic={[1,2,3]:'a',[4,5,6]:'b'}
print(dic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b170b655a1aa> in <cell line: 2>()
#       1 #When we take list as a key it returns Type error
# ----> 2 dic={[1,2,3]:'a',[4,5,6]:'b'}
#       3 print(dic)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# An important feature of the dictionary is that keys have to be unique for that dictionary. For example:

# %%
#When you have duplicate keys, as in the case of your dictionary d1, the last occurrence of the key will override any previous ones
#Therefore  when you print d1, the value associated with the key 3 will be the one from the last occurrence
d1={1:'hello',2:'world', 3:'error', 3:'trial'}
print(d1)
# Out:
# {1: 'hello', 2: 'world', 3: 'trial'}

# %%
#To demonstrate that dictionaries are ordered
dicto={'a': 1, 'b': 2, 'c': 3, 'd': 4}
print("Original order of dictionary:")
for key, value in dicto.items():
    print(key, value)

#Modify the dictionary
dicto['b']=10
print("\nOrder after modification:")
for key, value in dicto.items():
    print(key, value)
# Out:
# Original order of dictionary:
# a 1
# b 2
# c 3
# d 4
#
# Order after modification:
# a 1
# b 10
# c 3
# d 4

# %% [markdown]
# This behavior ensures that the order in which items are inserted into the dictionary is preserved when iterating over the dictionary

# %%
#Both a and b look differently ordered but when compared return True

b = {'three':3, 'one':1,"two":2}
print (b)

a = {'one':1, 'two':2, 'three':3}
print(a)
print(a==b)
# Out:
# {'three': 3, 'one': 1, 'two': 2}
# {'one': 1, 'two': 2, 'three': 3}
# True

# %% [markdown]
# **Adding Elements to a Dictionary**
#
# Dictionaries are mutable so we can modify the values associated with the keys and add new key-value pairs.

# %%
d={}
d['name']='Anushka'
d['age']=19
d['Program']='BTech'
d['Branch']='Electrical'
print(d)
# Out:
# {'name': 'Anushka', 'age': 19, 'Program': 'BTech', 'Branch': 'Electrical'}

# %% [markdown]
# To delete a key:value pair we use the del statement.
#
# Syntax:
#
# del dict[key]

# %%
#To delete a certain key:value pair
del d['Branch']
print (d)
# Out:
# {'name': 'Anushka', 'age': 19, 'Program': 'BTech'}

# %%
#To delete a key:value pair using the value we need to iterate
# Find the key associated with the value 'John' and delete the key-value pair
print(d.items())
for key, value in d.items():
    if value=='BTech':
        del d[key]
        break #exit loop after first occurrence
print(d)
# Out:
# dict_items([('name', 'Anushka'), ('age', 19), ('Program', 'BTech')])
# {'name': 'Anushka', 'age': 19}

# %% [markdown]
# **Important Operation:**
#
# Modifying entries

# %%
print("Before modification", a)
a['one']=5
print("After modification", a)
# Out:
# Before modification {'one': 1, 'two': 2, 'three': 3}
# After modification {'one': 5, 'two': 2, 'three': 3}

# %% [markdown]
# To check if a key exists , we use the 'in' keyword and 'not in' for the opposite.

# %%
if 'one' in a:
    print('present')
# Out:
# present

# %% [markdown]
# Performing list(dictionary) returns a list of all the keys present in the dictionary in the order in which they were inserted.

# %%
list(a)
# Out:
# ['one', 'two', 'three']

# %%
#If we want the above to be be sorted we use sorted(dictionary)
sorted(a)
#As you can see, the keys are sorted alphabetically.
# Out:
# ['one', 'three', 'two']

# %% [markdown]
# **Dictionary Methods**
#
# Dictionaries can be manipulated through various methods:
#
# 1) keys():
#
# Returns a view object. The view object contains a list of the keys in the dictionary.
# Syntax: dict.keys()

# %%
a.keys()
# Out:
# dict_keys(['one', 'two', 'three'])

# %% [markdown]
# 2) values():
#
# Returns a view object that displays a list of all the values in the dictionary. Syntax: dict.values()

# %%
a.values()
# Out:
# dict_values([5, 2, 3])

# %% [markdown]
# 3) items():
#
# Returns a view object that displays a list of key-value tuples in the dictionary. Syntax: dict.items()

# %%
a.items()
# Out:
# dict_items([('one', 5), ('two', 2), ('three', 3)])

# %% [markdown]
# These view objects are dynamic, meaning that if the underlying dictionary changes (keys are added or removed), the view reflects those changes automatically.
#
# However, the view objects themselves are not actual lists or sets; they are more memory-efficient, providing a dynamic and up-to-date view on the dictionary without duplicating the data.

# %%
my_dict = {'one': 1, 'two': 2, 'three': 3}

# Get a view of keys
keys_view = my_dict.keys()

# Add a new key-value pair to the dictionary
my_dict['four'] = 4

# Print the view again
print(keys_view)

#keys_view will automatically include the new key 'four' because it reflects the changes made to the underlying dictionary.
# Out:
# dict_keys(['one', 'two', 'three', 'four'])

# %% [markdown]
# 4) clear():
#
# Removes all the elements from the dictionary.
#
# Syntax: dict.clear()

# %%
a.clear()
print(a)
#Returns empty dictionary
# Out:
# {}

# %% [markdown]
# 5) get():
#
# Returns the value of the specified key
#
# Synatx: dict.get(key)

# %%
print(b)
b.get('three','None')
#Suppose the key is not present
b.get('ten','Key not present')
#It prints the default value
# Out:
# {'three': 3, 'one': 1, 'two': 2}
# 'Key not present'

# %% [markdown]
# 6) pop():
#
# Removes the element with the specified key
#
# Syntax: dict.pop(key)

# %%
b.pop('one')
print(b)
# Out:
# {'three': 3, 'two': 2}

# %% [markdown]
# 7) popitem():
#
# Removes the last key-value pair that we have inserted.
#
# Synatx: dict.popitem()

# %%
b.popitem()
print(b)
# Out:
# {'three': 3}

# %% [markdown]
# 8) setdefault():
#
# Sets the key to a default value if the key is not present in the dictionary.
#
# Synatx: dict.setdefault(key, default="None")

# %%
b.setdefault("four",5)
print(b)
# Out:
# {'three': 10, 'four': 5, 1: 'a', 'six': 6}

# %% [markdown]
# 9) update() :
#
# adds a key:value pair to the dictionary
#
# Synatx: dict.update([mapping])

# %%
b.update({'six':6})
print(b)
# Out:
# {'three': 10, 'four': 5, 1: 'a', 'six': 6}

# %% [markdown]
# 10) dict() constructor:
#
# It builds dictionaries directly from sequence of key-value pairs.

# %%
d= dict([('red', 4), ('blue', 7), ('pink', 8)])
print(d)
# Out:
# {'red': 4, 'blue': 7, 'pink': 8}

# %% [markdown]
# 11) copy():
#
# Returns a shallow copy of the dictionary.
#
# Synatx:  dict.copy()

# %%
c=b.copy()
print(c)
b['three']= 10
print(c)

#altering the objects in original dictionary will affect it’s copy as well
# Out:
# {'three': 10, 'four': 5, 1: 'a', 'six': 6}
# {'three': 10, 'four': 5, 1: 'a', 'six': 6}

# %% [markdown]
# 12) fromekeys():
#
# Returns a new dictionary with keys from a supplied iterable and values all set to specified value
#
# Syntax: dict.fromkeys(iterable[,value])

# %%
nums=[12,13,14,15]
num_dict={}
num_dict=num_dict.fromkeys(nums)
print(num_dict)
#or
nums_dict={}.fromkeys(nums, "Numbers")
print(nums_dict)
# Out:
# {12: None, 13: None, 14: None, 15: None}
# {12: 'Numbers', 13: 'Numbers', 14: 'Numbers', 15: 'Numbers'}

# %% [markdown]
# **IMPORTANT FUNCTIONS**
#
# 1)len
#
# Returns an int type specifying number of elements in the collection

# %%
len(b)
# Out:
# 3

# %% [markdown]
# 2)all
#
# Returns a Boolean value that indicates whether the collection contains only values that evaluate to True

# %%
all(b)
# Out:
# True

# %% [markdown]
# 3) any()
#
# Returns a Boolean value that indicates whether the collection contains any values that evaluate to True.

# %%
any(d)
# Out:
# True

# %% [markdown]
# **Looping**
#
# When looping through dictionaries, the key and corresponding value can be retrieved at the same time using the items() method.

# %%
for keys, values in d.items():
    print( keys, values)
# Out:
# red 4
# blue 7
# pink 8

# %%
#the above can also be written as
for key in d:
    print(key, d[key])
# Out:
# red 4
# blue 7
# pink 8

# %% [markdown]
# **Dictionary Comprehension**
#
# Similar to list comprehensions, you can use dictionary comprehensions to create dictionaries in a concise way.

# %%
squares= {x: x**2 for x in range(10)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# **Nested Dictionary**
#
# One or more dictionaries can be values in another dictionary.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Source of image: https://www.geeksforgeeks.org/python-dictionary/

# %%
d1={"colours":d}
print(d1)

#To access the number of colour blue
print(d1['colours']['blue'])
# Out:
# {'colours': {'red': 4, 'blue': 7, 'pink': 8}}
# 7

# %% [markdown]
# Dictionary keys are case sensitive, the same name but different cases of Key will be treated distinctly.

# %% [markdown]
# **PRACTICAL USE CASES**

# %% [markdown]
# 1) JSON LIKE DATA

# %%
#we can represent data similar to json
student={
    'name': 'Mahi',
    'age':20,
    'address': 'Lucknow'
}

# %% [markdown]
# 2) Configurations:

# %%
#Dictionaries are handy for storing configuration settings.

config = {
    'debug_mode': True,
    'max_connections': 100,
    'timeout': 30
}

# %% [markdown]
# 3. Efficient Lookups:

# %%
if 'age' in my_dict:
    print('Age is present:', my_dict['age'])
